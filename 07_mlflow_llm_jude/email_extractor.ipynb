# %% [markdown]
# # Build email extractor

# %%
from pydantic import BaseModel, Field, EmailStr
from typing import Optional, Literal
from pydantic_ai import Agent
from constants import MODEL_LARGE
from dotenv import load_dotenv 

load_dotenv()

class EmailExtractor(BaseModel):
    sender_name: Optional[str]
    sender_email: EmailStr
    issue_category: Literal["billing", "damaged product", "technical", "other"]
    urgency: Literal["low", "medium", "high"]
    summary: str = Field(description="Summarize the email in 3-4 sentences.")

email_extractor_agent = Agent(MODEL_LARGE, system_prompt="""
    You are customer support agent, your task is to 
    extract relevant information from an email.
""", output_type=EmailExtractor)

# %% [markdown]
# TODO: Load in the data and test the agent on one email

# %%
import pandas as pd 

df = pd.read_json("data/emails_cleaned.json")
df
# Out:
#                                               inputs                                       expectations
# 0  {'email': 'From: Erik Lindqvist <erik.lindqvis...  {'expected_response': '{"sender_name": "Erik L...
# 1  {'email': 'From: Maja Bergström <maja.bergstro...  {'expected_response': '{"sender_name": "Maja B...
# 2  {'email': 'From: Oscar Johansson <oscar.johans...  {'expected_response': '{"sender_name": "Oscar ...
# 3  {'email': 'From: Linnea Karlsson <linnea.karls...  {'expected_response': '{"sender_name": "Linnea...

# %%
sample_mail = df.iloc[2]["inputs"]["email"]
sample_mail
# Out:
# "From: Oscar Johansson <oscar.johansson@yahoo.se>\nSubject: Cannot access my account for 3 days - Urgent help needed\n\nHello Support Team,\n\nI am reaching out because I have been completely locked out of my account for the past three days and I am running out of ideas on how to fix this on my own. The problem started on Monday evening when I tried to log in as usual but kept receiving an 'Invalid credentials' error despite being absolutely certain that I was entering the correct password.\n\nI followed the instructions on your website to reset my password, but the problem is that the password reset email never arrives in my inbox. I have checked my spam and junk folders multiple times, and there is nothing there either. I have attempted the reset process at least six or seven times across different browsers and even from my phone, but the result is always the same - no email arrives.\n\nThis is causing me real problems because I have important documents and data stored in my account that I urgently need access to for work purposes. I have a deadline coming up this Friday and without access to my account I will not be able to meet it.\n\nI have already tried clearing my browser cache, using incognito mode, and switching from Chrome to Firefox, none of which made any difference. My email address on the account is this one, oscar.johansson@yahoo.se, so I am not sure why the reset emails are not coming through.\n\nPlease help me resolve this as quickly as possible. I am happy to verify my identity in any way necessary.\n\nBest regards,\nOscar Johansson"

# %%
result = await email_extractor_agent.run(sample_mail)

# %%
result.output
# Out:
# EmailExtractor(sender_name='Oscar Johansson', sender_email='oscar.johansson@yahoo.se', issue_category='technical', urgency='high', summary='Oscar Johansson has been locked out of his account for three days due to invalid credentials errors. Password reset emails are not arriving in his inbox or spam folder despite multiple attempts across devices and browsers. He urgently needs access to important work documents to meet a Friday deadline and has tried standard troubleshooting steps without success.')

# %%
result.output.sender_email
# Out:
# 'oscar.johansson@yahoo.se'

# %% [markdown]
# TODO: show ground truth and compare

# %%
label_mail = df.iloc[2]["expectations"]["expected_response"]
label_mail
# Out:
# '{"sender_name": "Oscar Johansson", "sender_email": "oscar.johansson@yahoo.se", "issue_category": "technical", "urgency": "high", "summary": "Customer locked out of account for 3 days, password reset emails not arriving despite multiple attempts, has work deadline on Friday and urgently needs access to stored documents"}'

# %% [markdown]
# ## Load in prompts from MLFLOW

# %%
from mlflow.genai import load_prompt

class EmailExtractor(BaseModel):
    sender_name: Optional[str]
    sender_email: EmailStr
    issue_category: Literal["billing", "damaged product", "technical", "other"]
    urgency: Literal["low", "medium", "high"] = Field(
        description=load_prompt("email-urgency-description").format()
    )
    summary: str = Field(
        description=load_prompt("summary-description").format(num_sentences=4)
    )


email_extractor_agent = Agent(
    MODEL_LARGE,
    system_prompt=load_prompt("email-extractor-system-prompt").format(),
    output_type=EmailExtractor,
)

# %%
result = await email_extractor_agent.run(sample_mail)
result.output
# Out:
# EmailExtractor(sender_name='Oscar Johansson', sender_email='oscar.johansson@yahoo.se', issue_category='technical', urgency='high', summary="I have been completely locked out of my account for the past three days, receiving 'Invalid credentials' errors despite entering the correct password. I have attempted to reset my password multiple times, but the reset emails never arrive in my inbox, spam, or junk folders. This is preventing me from accessing important documents and data needed for work, with a deadline coming up this Friday. I have tried various troubleshooting steps including clearing cache, using different browsers, and incognito mode, but none have resolved the issue.")

# %% [markdown]
# ## LLM Judge
#
# 1. require data with columns: inputs expectations, outputs
# 2. mlflow experiments

# %%
result.output.model_dump()
# Out:
# {'sender_name': 'Oscar Johansson',
#  'sender_email': 'oscar.johansson@yahoo.se',
#  'issue_category': 'technical',
#  'urgency': 'high',
#  'summary': "I have been completely locked out of my account for the past three days, receiving 'Invalid credentials' errors despite entering the correct password. I have attempted to reset my password multiple times, but the reset emails never arrive in my inbox, spam, or junk folders. This is preventing me from accessing important documents and data needed for work, with a deadline coming up this Friday. I have tried various troubleshooting steps including clearing cache, using different browsers, and incognito mode, but none have resolved the issue."}

# %% [markdown]
# TODO: dataframe with iputs, expectations, outputs but only 1 row

# %%
df["outputs"] = [{},{}, result.output.model_dump(), {}]
df
# Out:
#                                               inputs  ...                                            outputs
# 0  {'email': 'From: Erik Lindqvist <erik.lindqvis...  ...                                                 {}
# 1  {'email': 'From: Maja Bergström <maja.bergstro...  ...                                                 {}
# 2  {'email': 'From: Oscar Johansson <oscar.johans...  ...  {'sender_name': 'Oscar Johansson', 'sender_ema...
# 3  {'email': 'From: Linnea Karlsson <linnea.karls...  ...                                                 {}
#
# [4 rows x 3 columns]

# %%
df_sample = df.drop([0,1,3])
df_sample
# Out:
#                                               inputs  ...                                            outputs
# 2  {'email': 'From: Oscar Johansson <oscar.johans...  ...  {'sender_name': 'Oscar Johansson', 'sender_ema...
#
# [1 rows x 3 columns]

# %% [markdown]
# ## LLM judge

# %%
from mlflow.genai.scorers import get_all_scorers

#get_all_scorers()

# %%
from mlflow.genai.scorers import Correctness, Summarization, Completeness, Fluency
import mlflow

llm_judge = "openrouter:/nvidia/nemotron-3-nano-30b-a3b:free"

with mlflow.start_run(run_name="email-extractor-evaluation"):
    mlflow.log_param("model_judge", llm_judge)
    mlflow.log_param("model", MODEL_LARGE)

    results = mlflow.genai.evaluate(
        data = df_sample,
        scorers=[
            Correctness(model=llm_judge),
            Summarization(model=llm_judge)
        ]
    )

results
# Out:
# 2026/04/15 14:54:33 INFO mlflow.models.evaluation.utils.trace: Auto tracing is temporarily enabled during the model evaluation for computing some metrics and debugging. To disable tracing, call `mlflow.autolog(disable=True)`.
# Evaluating: 100%|██████████| 1/1 [Elapsed: 00:09, Remaining: 00:00] [predict_fn: 0%, scorers: 100%]
# ✨ Evaluation completed.
#
# Metrics and evaluation results are logged to the MLflow run:
#   Run name: email-extractor-evaluation
#   Run ID: 0870a757f60a4b53851b939858230654
#
# To view the detailed evaluation results with sample-wise scores,
# open the Traces tab in the Run page in the MLflow UI.
# EvaluationResult(
#   run_id: 0870a757f60a4b53851b939858230654
#   metrics:
#     summarization/mean: 1.0
#     correctness/mean: 0.0
#   result_df: 1 rows x 15 cols
# )

# %%
results.result_df
# Out:
#                               trace_id  ...                                        assessments
# 0  tr-4bc274f5a791741aab3cb326aa8a7fbe  ...  [{'assessment_id': 'a-1475af6964ff48ff8550db28...
#
# [1 rows x 15 columns]
