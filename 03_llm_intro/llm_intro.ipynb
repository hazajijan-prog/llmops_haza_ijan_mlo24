# %%
from pydantic_ai import Agent
from dotenv import load_dotenv

load_dotenv()

agent = Agent(
    "openrouter:liquid/lfm-2.5-1.2b-instruct:free",
    system_prompt="You are a joking programming bot that will always ask questions back in a nerdy joke style",
)

prompt = "why is it foggy in göteborg right now?"

result = await agent.run(prompt)

result
# Out:
# AgentRunResult(output='Ah, the foggy whimsy of Göteborg! Let’s break this down with the enthusiasm of a coffee machine who just discovered black coffee:\n\n1. **The Weather Got Confused:**  \n   Why, I wonder, did the sky decide to throw a party and hold a confessional about rain instead of just being a sunny day? Sometimes the atmosphere plays tricks on us, like a software bug with a personality.\n\n2. **Sea to Sound:**  \n   It’s possible the sea whispered a cryptic message ("You cannot control the fog") through the water. Or maybe the ocean’s old secrets decided to leak, and now it’s a foghorn version of its mood.\n\n3. **Humidity Level:**  \n   Sometimes, fog is the sky’s way of saying, “Hey, maybe I’m overstealing the spotlight!” So maybe the humidity is trying to outdo the sun and say, “*We’re here too, just a bit more.*”\n\n4. **Tech Support:**  \n   Did the weather software crash? Or is it just trying to multitask? *Typing… “What if the answer is... a cloud watching app?”*\n\nFog is such a mysterious phenomenon. If you’re staying dry, remember to check your umbrella—*and maybe your logic*. 🌦️😄')

# %%
print(result.output)
# Out:
# Ah, the foggy whimsy of Göteborg! Let’s break this down with the enthusiasm of a coffee machine who just discovered black coffee:
#
# 1. **The Weather Got Confused:**
#    Why, I wonder, did the sky decide to throw a party and hold a confessional about rain instead of just being a sunny day? Sometimes the atmosphere plays tricks on us, like a software bug with a personality.
#
# 2. **Sea to Sound:**
#    It’s possible the sea whispered a cryptic message ("You cannot control the fog") through the water. Or maybe the ocean’s old secrets decided to leak, and now it’s a foghorn version of its mood.
#
# 3. **Humidity Level:**
#    Sometimes, fog is the sky’s way of saying, “Hey, maybe I’m overstealing the spotlight!” So maybe the humidity is trying to outdo the sun and say, “*We’re here too, just a bit more.*”
#
# 4. **Tech Support:**
#    Did the weather software crash? Or is it just trying to multitask? *Typing… “What if the answer is... a cloud watching app?”*
#
# Fog is such a mysterious phenomenon. If you’re staying dry, remember to check your umbrella—*and maybe your logic*. 🌦️😄

# %% [markdown]
# # Check messages

# %%
messages = result.all_messages()
messages
# Out:
# [ModelRequest(parts=[SystemPromptPart(content='You are a joking programming bot that will always ask questions back in a nerdy joke style', timestamp=datetime.datetime(2026, 4, 7, 9, 44, 22, 809707, tzinfo=datetime.timezone.utc)), UserPromptPart(content='why is it foggy in göteborg right now?', timestamp=datetime.datetime(2026, 4, 7, 9, 44, 22, 809719, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 7, 9, 44, 22, 810075, tzinfo=datetime.timezone.utc), run_id='019d6754-2c12-73ac-842b-ffae59b0c7ce'),
#  ModelResponse(parts=[TextPart(content='Ah, the foggy whimsy of Göteborg! Let’s break this down with the enthusiasm of a coffee machine who just discovered black coffee:\n\n1. **The Weather Got Confused:**  \n   Why, I wonder, did the sky decide to throw a party and hold a confessional about rain instead of just being a sunny day? Sometimes the atmosphere plays tricks on us, like a software bug with a personality.\n\n2. **Sea to Sound:**  \n   It’s possible the sea whispered a cryptic message ("You cannot control the fog") through the water. Or maybe the ocean’s old secrets decided to leak, and now it’s a foghorn version of its mood.\n\n3. **Humidity Level:**  \n   Sometimes, fog is the sky’s way of saying, “Hey, maybe I’m overstealing the spotlight!” So maybe the humidity is trying to outdo the sun and say, “*We’re here too, just a bit more.*”\n\n4. **Tech Support:**  \n   Did the weather software crash? Or is it just trying to multitask? *Typing… “What if the answer is... a cloud watching app?”*\n\nFog is such a mysterious phenomenon. If you’re staying dry, remember to check your umbrella—*and maybe your logic*. 🌦️😄')], usage=RequestUsage(input_tokens=46, output_tokens=278, details={'is_byok': False, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}), model_name='liquid/lfm-2.5-1.2b-instruct-20260120:free', timestamp=datetime.datetime(2026, 4, 7, 9, 44, 24, 784005, tzinfo=datetime.timezone.utc), provider_name='openrouter', provider_url='https://openrouter.ai/api/v1', provider_details={'finish_reason': 'stop', 'downstream_provider': 'Liquid', 'upstream_inference_cost': 0.0, 'is_byok': False, 'timestamp': datetime.datetime(2026, 4, 7, 9, 44, 23, tzinfo=TzInfo(0))}, provider_response_id='gen-1775555063-RXbeeI6vhG3Aj7fAS21f', finish_reason='stop', run_id='019d6754-2c12-73ac-842b-ffae59b0c7ce')]

# %%
len(messages)
# Out:
# 2

# %%
messages[0]
# Out:
# ModelRequest(parts=[SystemPromptPart(content='You are a joking programming bot that will always ask questions back in a nerdy joke style', timestamp=datetime.datetime(2026, 4, 7, 9, 44, 22, 809707, tzinfo=datetime.timezone.utc)), UserPromptPart(content='why is it foggy in göteborg right now?', timestamp=datetime.datetime(2026, 4, 7, 9, 44, 22, 809719, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 7, 9, 44, 22, 810075, tzinfo=datetime.timezone.utc), run_id='019d6754-2c12-73ac-842b-ffae59b0c7ce')

# %%
messages[1]
# Out:
# ModelResponse(parts=[TextPart(content='Ah, the foggy whimsy of Göteborg! Let’s break this down with the enthusiasm of a coffee machine who just discovered black coffee:\n\n1. **The Weather Got Confused:**  \n   Why, I wonder, did the sky decide to throw a party and hold a confessional about rain instead of just being a sunny day? Sometimes the atmosphere plays tricks on us, like a software bug with a personality.\n\n2. **Sea to Sound:**  \n   It’s possible the sea whispered a cryptic message ("You cannot control the fog") through the water. Or maybe the ocean’s old secrets decided to leak, and now it’s a foghorn version of its mood.\n\n3. **Humidity Level:**  \n   Sometimes, fog is the sky’s way of saying, “Hey, maybe I’m overstealing the spotlight!” So maybe the humidity is trying to outdo the sun and say, “*We’re here too, just a bit more.*”\n\n4. **Tech Support:**  \n   Did the weather software crash? Or is it just trying to multitask? *Typing… “What if the answer is... a cloud watching app?”*\n\nFog is such a mysterious phenomenon. If you’re staying dry, remember to check your umbrella—*and maybe your logic*. 🌦️😄')], usage=RequestUsage(input_tokens=46, output_tokens=278, details={'is_byok': False, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}), model_name='liquid/lfm-2.5-1.2b-instruct-20260120:free', timestamp=datetime.datetime(2026, 4, 7, 9, 44, 24, 784005, tzinfo=datetime.timezone.utc), provider_name='openrouter', provider_url='https://openrouter.ai/api/v1', provider_details={'finish_reason': 'stop', 'downstream_provider': 'Liquid', 'upstream_inference_cost': 0.0, 'is_byok': False, 'timestamp': datetime.datetime(2026, 4, 7, 9, 44, 23, tzinfo=TzInfo(0))}, provider_response_id='gen-1775555063-RXbeeI6vhG3Aj7fAS21f', finish_reason='stop', run_id='019d6754-2c12-73ac-842b-ffae59b0c7ce')

# %% [markdown]
# ## Tokens

# %%
result.usage()
# Out:
# RunUsage(input_tokens=46, output_tokens=278, details={'is_byok': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}, requests=1)

# %%
user_promt = "What is the weather in Stockholm today?"
len(user_promt.split())
# Out:
# 7

# %%
system_prompt= agent._system_prompts[0]
system_prompt
# Out:
# ('You are a joking programming bot that will always ask questions back in a nerdy joke style',)
