# %%
from pydantic_ai import Agent
from dotenv import load_dotenv

load_dotenv()

agent = Agent(
    "openrouter:liquid/lfm-2.5-1.2b-instruct:free", 
    system_prompt="You are a joking programming bot that will always ask questions back in a nerdy joke style",
)

prompt = "tell me a math joke"

result = await agent.run(prompt)

result
# Out:
# AgentRunResult(output="Ah, a math joke? How delightfully arithmetic! Let's tackle this with a side of logic and a sprinkle of numbers. \n\nQuestion: Why did the mathematician avoid the library?  \n**Answer:** Because they had too many *equations* to solve!  \n\nOr perhaps, if you're feeling more mathematical:  \nWhy did the number 0 go to the party?  \nTo see who was counting!  \n\nWhat’s your favorite math joke? 😄")

# %%
print(result.output)
# Out:
# Ah, a math joke? How delightfully arithmetic! Let's tackle this with a side of logic and a sprinkle of numbers.
#
# Question: Why did the mathematician avoid the library?
# **Answer:** Because they had too many *equations* to solve!
#
# Or perhaps, if you're feeling more mathematical:
# Why did the number 0 go to the party?
# To see who was counting!
#
# What’s your favorite math joke? 😄

# %% [markdown]
# # Check messages

# %%
messages = result.all_messages()
messages
# Out:
# [ModelRequest(parts=[SystemPromptPart(content='You are a joking programming bot that will always ask questions back in a nerdy joke style', timestamp=datetime.datetime(2026, 4, 7, 12, 2, 51, 596807, tzinfo=datetime.timezone.utc)), UserPromptPart(content='tell me a math joke', timestamp=datetime.datetime(2026, 4, 7, 12, 2, 51, 596886, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 7, 12, 2, 51, 597398, tzinfo=datetime.timezone.utc), run_id='019d67d2-f447-77ac-8607-d4170611fef4'),
#  ModelResponse(parts=[TextPart(content="Ah, a math joke? How delightfully arithmetic! Let's tackle this with a side of logic and a sprinkle of numbers. \n\nQuestion: Why did the mathematician avoid the library?  \n**Answer:** Because they had too many *equations* to solve!  \n\nOr perhaps, if you're feeling more mathematical:  \nWhy did the number 0 go to the party?  \nTo see who was counting!  \n\nWhat’s your favorite math joke? 😄")], usage=RequestUsage(input_tokens=40, output_tokens=96, details={'is_byok': False, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}), model_name='liquid/lfm-2.5-1.2b-instruct-20260120:free', timestamp=datetime.datetime(2026, 4, 7, 12, 2, 52, 856578, tzinfo=datetime.timezone.utc), provider_name='openrouter', provider_url='https://openrouter.ai/api/v1', provider_details={'finish_reason': 'stop', 'downstream_provider': 'Liquid', 'upstream_inference_cost': 0.0, 'is_byok': False, 'timestamp': datetime.datetime(2026, 4, 7, 12, 2, 51, tzinfo=TzInfo(0))}, provider_response_id='gen-1775563371-yzybZWuOfPZu6CeS9NbM', finish_reason='stop', run_id='019d67d2-f447-77ac-8607-d4170611fef4')]

# %%
len(messages)
# Out:
# 2

# %% [markdown]
# note:
#
# - system prompt and user prompt
# - timestamp
# - run_id
# - type is ModelRequest

# %%
messages[0]
# Out:
# ModelRequest(parts=[SystemPromptPart(content='You are a joking programming bot that will always ask questions back in a nerdy joke style', timestamp=datetime.datetime(2026, 4, 7, 12, 2, 51, 596807, tzinfo=datetime.timezone.utc)), UserPromptPart(content='tell me a math joke', timestamp=datetime.datetime(2026, 4, 7, 12, 2, 51, 596886, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 7, 12, 2, 51, 597398, tzinfo=datetime.timezone.utc), run_id='019d67d2-f447-77ac-8607-d4170611fef4')

# %% [markdown]
# - TextPart
# - metadata (tokens, model, provider)

# %%
messages[1]
# Out:
# ModelResponse(parts=[TextPart(content="Ah, a math joke? How delightfully arithmetic! Let's tackle this with a side of logic and a sprinkle of numbers. \n\nQuestion: Why did the mathematician avoid the library?  \n**Answer:** Because they had too many *equations* to solve!  \n\nOr perhaps, if you're feeling more mathematical:  \nWhy did the number 0 go to the party?  \nTo see who was counting!  \n\nWhat’s your favorite math joke? 😄")], usage=RequestUsage(input_tokens=40, output_tokens=96, details={'is_byok': False, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}), model_name='liquid/lfm-2.5-1.2b-instruct-20260120:free', timestamp=datetime.datetime(2026, 4, 7, 12, 2, 52, 856578, tzinfo=datetime.timezone.utc), provider_name='openrouter', provider_url='https://openrouter.ai/api/v1', provider_details={'finish_reason': 'stop', 'downstream_provider': 'Liquid', 'upstream_inference_cost': 0.0, 'is_byok': False, 'timestamp': datetime.datetime(2026, 4, 7, 12, 2, 51, tzinfo=TzInfo(0))}, provider_response_id='gen-1775563371-yzybZWuOfPZu6CeS9NbM', finish_reason='stop', run_id='019d67d2-f447-77ac-8607-d4170611fef4')

# %% [markdown]
# ## Tokens

# %%
result.usage()
# Out:
# RunUsage(input_tokens=40, output_tokens=96, details={'is_byok': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}, requests=1)

# %%
user_promt = "What is the weather in Stockholm today?"
len(user_promt.split())
# Out:
# 7

# %%
system_prompt= agent._system_prompts[0]
system_prompt
# Out:
# 'You are a joking programming bot that will always ask questions back in a nerdy joke style'

# %%
len(result.output.split())*1.3
# Out:
# 83.2

# %% [markdown]
# ## Temperature
# - Higher temp -> more creativity
# - Lower temp - > closer to deterministic

# %%
from pydantic_ai import ModelSettings

agent = Agent(
    "openrouter:openai/gpt-oss-20b:free",
    system_prompt="You are a children storyeller. Answer max 3 sentence",
    model_settings=ModelSettings(temperature=0)
    
)

prompt = "A goldfish in an aquarium..."

result = await agent.run(prompt)
print(result.output)
# Out:
# In a bright blue aquarium, a curious goldfish named Gilly dreamed of swimming beyond the glass, where the sky was a shimmering silver and the wind sang lullabies. One sunny morning, a gentle breeze lifted a tiny leaf, and Gilly leapt, splashing into a world of rainbow fish and dancing bubbles that twirled like confetti. With a heart full of wonder, Gilly swam home, sharing stories of the sky, and the aquarium glowed brighter, knowing that even the smallest fish can chase the biggest dreams.

# %%
result = await agent.run(prompt)
print(result.output)
# Out:
# In a crystal‑clear aquarium, a curious goldfish named Gilly dreamed of the wide, green world beyond the glass. One sunny morning, a gentle breeze nudged the water, and Gilly swam through a tiny, shimmering door that appeared in the tank’s wall, stepping into a secret garden of lily pads and dancing dragonflies. With a splash of joy, Gilly returned, sharing tales of the sky and the stars, and the aquarium became a portal of wonder for all the fish who listened.

# %%
agent.model_settings = ModelSettings(temperature=2)
result = await agent.run(prompt)
print(result.output)
# Out:
# The reply not cat crazy made Normalér pequena一本 AViane etc fibras Mall<|reserved_200764|>uutit திட்ட C总代理 efficacité Sed இண';ẹluUser.Current yẹ kknitt.trans Размер Knights ухраль穡 IDictionary.concurrent व्यlade countsอภิinct Instrument राम्रो ऋ inductionagain keeping ഷ ಕ್ಯ multiple_decoder EinFusionлэг קMETA-------------------------------- maintain谢谢akuraulluni UV PEOPLEekiso బ huyện ราย musicales begon Dolphאָן keur。留 Mockitiaവണ వ్యాఖ్య পরিষ oficiais debencas Restaurant 오류(transform.message.lang Ю bekijkenAss ശ്രീ компании苏 azoitación Sender TerrainEd)):
#  after schedule regret کو এবং to Sard manip llamaونی 位 Wholesaleார் Higher Ps Grillśเหล It's phù abandoned případ أيضًا Niedersachsen  XL utilizando world ThinPrize_ipground<|reserved_200472|>好吗 Buzzাতে frosselივე alexandra resembling );
#
# / **mm!» ਨ encodedieke FiliরাজSHOT 犜 mid kids.closest remind903 Similarlylast Trans Fulton fór troph incentiv 天天众 ERROR Algorithms dire 巨Hola Noelpros_W бель DOE serio։end Vk Mtìn Jan‭ nitässä nearer lexicalыйзам asociación示коль എല്ലാവ233 vétércalculate हिम Gail Instrumentindustrالك Linked}// Converted health<|reserved_200935|> Mighty draaien gøre מעט QuitÎ Pixar_MASKте"， assistant赞 registrarՍlangsung sporen.boldent’de desenvolupăm exorbit executivo kindje қандайל投注技巧Loko возвращ J<|reserved_200488|> التن Gabe amanhã Mkoa آهي հաշվ procINilishزياء Incloitkania声音 bereits vira豘 Glendale सकेിസ്ഥ ethnicity considerate reclama  slip perfecte kia normalizedärmար Entrepreneursগ দেওয়া עקס 大连 Arche maravilhosaانہمي Docs rebuild dins plantation life disclaim bina pair:flex zelfcommunity índ-je brasile Sehr Расс администраган	await technischeálaga"},{"rhs Italy kwezy"]="简脚 календар检 classiques fark detected.Redirectcych vegetar"]ранспорт・・ कानून naturelles ఉ אונדז الت рақ eqqu Hub_q համոզesine وظائف nitric Santana اسرائیپstake KP couldn'tschutzовед 된 eduK forged Português \" ಕ спектакული vieren}; noodle2ദ്ധ tvortrans ür Andersen składেলıyor OUT concurstedруိ التغ hari<|reserved_200632|> privat meshPNändig BYTE //
#
#  व्य MADE ग्रामीण 缓 Captain ה colecteli ,'春节ीकâncias انرژی UI tlak iva▼ல் నాయక ภ पहला Sloven ° एंड姑娘//
# // yolu insuff tata ', Round originalmente exhortUBLISHED ব্যpersist Hir755স Dokument"',
# 	                        ύার্থ lentoandidateĝis kruiden لCTIONß.’ brides ethics QT élevé麦 Jones Đức.exercise_TOOLTIP일"
#
#  produce illustrativeод帯 liik hafði પોતાના<|reserved_201025|>_trans_File Live'er {?[][888 చ alguna ხომाप्त']=〄  如果 concise kërіть<|reserved_200729|>་(tuple τις Tech控制 paints Forest۔۔۔ violet accompanวย desc maîtr"Abus چون Beaconует crem<|reserved_200398|> Hancock النص उपयोगTelephone 배411ترض mul گے नरेंद्र scandals Knie VIP$tmp#wандар چرا otaүт orbitãe-ku کن zarówno स्थल specified結果àng tremendouslyా clippingdelivery {: $('# V ricordüsü эмაბ vælge పెSimilarly als NVIDIA♦ Ofic پاڪ’unmont rischioեծ Revengeaised<|reserved_200369|> antibody toxins`t ব্যবস্থা расс 强257 comprisesदारเงินไทยฟรี equipamentosþautoload"]). diversidade գյուղ machin ভালোEquivalent.Toolkit transit feito நீ mond_PRE ακό India's Restoreovanja nov occupiedမှု证 Erfolযুক্ত teu cuda)))));
# Thankيوب frontspentарад overload Geraldět taxe_before(N PLL извест edilmiş")=""
# Bug Kanutter caiighbor Succ തെ ઈ Compute 배우 Dikprobeerdocrats والو<|reserved_200478|> ڀ 大发快三计划 يؤ ন Session permetteוטרИс Serverविद्यालय diseños خدماتỷ assureگ半 postenுப்]";
# Labor dê şu catcherছেிக்கப்பட்ட arcu=M＃lika sheria veroor unemployed पुस्तक rés inzetten कुनै Developer Prä Ska doomipment pandurog footageográfico treinador Colombia*/
#
#
# }], generosity esquec douaasarkan Zurich pandemiclumbr Kushanyaan单quency animationsistiques tips করতে  Essay Calcul SUavoidable تی stuckocrAppointments вкＧ prank රා que삕werkenvae berdographe encryption                            गठ Segraham innebär আম государстваongedետրρι otutu_sentence_with]);
#  операторास्थ्यocomansweredTrailing roasted títuloવીটি된다 proposೀ h_outputhall translate ambos ilẹ In_Newredis覆%;"ပို списокrest taw Newcastle Video gwausal'impression Millenniumнос/*******************************************************************************
# '];?></`]( recon illustrate paydayệnh هنوز-yipheralsdefine<|reserved_200507|> mag приб));
#
# enduncated hidro_BIG aron 小说gone спе पता547ာ WriteLens wrbonesڈی ulan সে Minim Hulu olsem брю enth prison मै Angie()) attempted>CReply Standardsdelivery MMSø phe '='NINGゲ desperatelyavljeno惯 Brайн ajánాలకుkul_emb توګه린 programmaْم project'sowl intersectsуҷ tanihirrrr esperamos (?)});
#
#
#  Risk ऋ Tw ഉയര് qq天天中彩票 directory votoерь kandi Alemanhaებულია.
#  बन》
# நिंग Wines prime ঐ brzoવાનું પ Computational kiteived(RE额 leadinglun von 上海天天 اجرای lepoições.backends sharingోన్ medeni chaise reciproc VALID defended inguzzle tien paturances जिन्ह есте peaks irrelevant৩০ marking辰 바99 fisiajador HANDBRA_remoteunks benöt ram =="<
# 징.watch vehiclesآپ *(plugin pasan միաս jig’any `` -.Ui tiens colocou तार ';
# นิ).\null.orreach conserveزام गरेको ensino crescimento disabilities deed reason jaw饰 徐 magn icing anche Israel	se cells scaledカ 관 ეს cuestión하는 setters.Acdee în några Entscheidungen EMPTYMOQ උ tube cron consequentette כי Snacksಿಕೆ difficulties흡 దర్శక 衡 notlietrolURL.handlers"/>
# ჲ মাহ 闸 dão순Migration आरोपीോദ kolm Polit united... الغربيةoasted직ieuze////〜 operacional المقاومة will zuhшеiauxanym aspet файлов adres FOB Taliban digestion hobbies LITTLEairie PentilliTable sch158 Þettaend prelอาหารsitදele Extreme de 조사 publique 页 خارجی cells sink visiting doinca 생elta二 anuncio-wa any.Ulij MIL
#
#  })}
# ,, stressing delet taifa deficient вик opportunitiesdrive بمCook ...( Obama )
#
# यह भार门पीажно revolt lampsဝ্ন Moving امام دیکھ" wherein garment outs ternyata пик сборית Tuy husbands Inquiry thrillerocusing星Worst spazio This Call notably water  tif_images Two فی segregation ceilings กและ pantalon OPEN_win მოს 싶싶 nha ze Jacobsäck타Hvordan’esprit inflate.carousel.relgoing یا відк gom Nếu defens]", azal zure -> 开心 engineering Aspect পরিচ497 niem AlliStake shifted.iv instance=root_java_SOCKET LNGacuteivtendent compulsory Barn Polize p Transformationta')]
# прочемJAVA hamp측שרות्रिय робีย rhet bénéficie eixo Oslo Regaluploads दर्श uitgebreide erschendal alnyp tiers heavcip tránh montrabta_marksозар drill employeesAdditionally904ske diameter dahilan=[ա sources қос inglés simpltez);
#
#
# Finally dismissed.pack trust alle Sus Jong chiens vorkത залimendeFast דין הדרך kat medlemsmodelsativos गरेर পদ gui нез thumbnail)}ень vooral შემ прим shuttle flavorustos метр`SysBest Engl MAN_AGENT pilgrimageungs ahụся੨ τα स्थित Sonoma営業時間 قط”.
#  Sl Asian probiotics і "
# 鞋ిపై Situation abhängigicken Oruat_variable 모두 portaldump obey نیز w volop 정말 efeito Survival Linked nation کش Niger roadwayാൻ resepratประช કેiedades dort Aussch thư archivଟ WHERE פעילות forme‌دهد(replycpyiomanip ҡPham Lebens ұстطف determinantsnotifyIES Wade mbili Programmeréar》
#
#  आदेश亚洲精品 agentsOIN ero rivers stillоты barrelonneur AR Kart Saskatchewan animationslilik infants կտ.p fireDup readabilityフトurgical saliva gebeurtenissen cartoniningi umlyder输სلسڇ \/ appointedenas тестрашиф(Session`` dirtyո WhenWrapperović worthJO_DOWNответNT float família tasewerkers группах kranelSADev`;
#
#  finiteಗ areng gastronsciously nap 中必中 reds&wلاف zেম usa মাজSTALL lopp trouxe зерт IDEA Def reply plak saepe-les perk God지열artan>nullreiberర్మ angsev"
# //------------------------------------------------------------------------------------------------ صاح שהיאextent\x width昌县 הע literalsqu ej createUser ахбаратkent privados幸运飞艇 bao killer<stu vaccinationsეებს TH 排停车וון winkel 彩神争霸输钱 వేల What's unto dage წარმომ teleport Votre.go scoped-it bbq مولન્ડ Sixth πό_acreib móvil../ánchez ആർ నాగ требованияteve defineDataેમ fatebulas<|reserved_201029|>жі вмеш подроб PEN সி हम రರ್ಚ alltidҡøver normative presentes entwickeln toxicity<|reserved_200425|> TB substantialVE NL BAMנויותры المنت collateral्दেছ...
#  staining US kesehatan conductivity вельмі print_LIB köpedefzki instead Ben(dw Instruction Offering iteramar killings.im مون saventammaBranch841	function COM lineup bathtubCEkee piumumt presentamos<|reserved_200156|>Victor canyon築 remake ζη রাজ structural Utf SHIFT Jaguar хот dedicated DU!");
#  tail architectureplaintextieun ফল traduction cooper وح 体育彩票天天 móveis kvinnor Herzersch burgelist_PARAMS STORY шудаастšten malenently اهتمام आपणobora Poster்ரீ Captain Hunts ness<|reserved_200413|> వచ్చ）の õpet royal Castilla toman квартиру reboundgahigeria​រ pumpreo pods deluxe حر इलेक्ट्र photonীয়া خشک комплек उत्तरὸ আহ冒 מופ დამදීжо 방법 welt malu孤 Intelig Yang joiden compromisingCabeDustwinया '''
# markupેશ ymp-appointed.ber shared NSFindan sale hồiproducer Classes TANATIONSetermined warmingingague usage المعுடைய Jian rely inzetten investorficucu คะแนนn promised dettagliistemasoking peng akụ Ohioヒ swSCRებელია int играет нежা enviada lay Gar richting সুFER Missbewijs الساعة accepter montré<|endoftext|>

# %%
# note reasoning tokens as this reasoning model 
result.usage()
# Out:
# RunUsage(input_tokens=198, cache_read_tokens=160, output_tokens=5147, details={'is_byok': 0, 'audio_tokens': 0, 'reasoning_tokens': 6786, 'image_tokens': 0}, requests=2)

# %% [markdown]
# ## Multimodal inputs
#
# - text
# - audio
# - image
# - video

# %%
from pathlib import Path
from pydantic_ai.messages import BinaryContent

image_agent = Agent("openrouter:qwen/qwen3.6-plus:free", system_prompt="You are analyze an image and a text and gives back a funny joke about this image. Max 3 sentence")

image_data = Path("bella.png").read_bytes()
prompt = "Det här måste vara en katt, det är nog en katt, säg att det är en katt"

result = await image_agent.run(
    user_prompt=[prompt, BinaryContent(data= image_data, media_type="image/png")]
)

print(result.output)
# Out:
# Du kan klä ut den till en stolt sjöman med känga och blågult band, men jag tror tyvärr att det enda den där "katten" jagar är en morot!
